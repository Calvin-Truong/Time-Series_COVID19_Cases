# %%
import pandas as pd
import numpy as np
# %matplotlib inline
pd.options.display.float_format = '{:.2f}'.format

#Read excel dataset
df = pd.read_excel('timeseries_covid19_us_confirmed.xlsx',index_col='date',parse_dates=True)

#since US is irrelevant in this dataframe
df = df.drop(columns=['country'])
df.head()
# Out:
#             total
# date
# 2020-01-22      1
# 2020-01-23      1
# 2020-01-24      2
# 2020-01-25      2
# 2020-01-26      5

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25',
#                '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29',
#                '2020-01-30', '2020-01-31',
#                ...
#                '2020-11-09', '2020-11-10', '2020-11-11', '2020-11-12',
#                '2020-11-13', '2020-11-14', '2020-11-15', '2020-11-16',
#                '2020-11-17', '2020-11-18'],
#               dtype='datetime64[ns]', name='date', length=302, freq=None)

# %%
#Create a simple moving average (SMA) - 1 week
df['7-day-SMA'] = df['total'].rolling (window = 7).mean() #Window is in relation to data
df.head(50)
# Out:
#             total  7-day-SMA
# date
# 2020-01-22      1        nan
# 2020-01-23      1        nan
# 2020-01-24      2        nan
# 2020-01-25      2        nan
# 2020-01-26      5        nan
# 2020-01-27      5        nan
# 2020-01-28      5       3.00
# 2020-01-29      6       3.71
# 2020-01-30      6       4.43
# 2020-01-31      8       5.29
# 2020-02-01      8       6.14
# 2020-02-02      8       6.57
# 2020-02-03     11       7.43
# 2020-02-04     11       8.29
# 2020-02-05     11       9.00
# 2020-02-06     12       9.86
# 2020-02-07     12      10.43
# 2020-02-08     12      11.00
# 2020-02-09     12      11.57
# 2020-02-10     12      11.71
# 2020-02-11     13      12.00
# 2020-02-12     13      12.29
# 2020-02-13     14      12.57
# 2020-02-14     14      12.86
# 2020-02-15     14      13.14
# 2020-02-16     14      13.43
# 2020-02-17     14      13.71
# 2020-02-18     14      13.86
# 2020-02-19     14      14.00
# 2020-02-20     14      14.00
# 2020-02-21     16      14.29
# 2020-02-22     16      14.57
# 2020-02-23     16      14.86
# 2020-02-24     16      15.14
# 2020-02-25     16      15.43
# 2020-02-26     16      15.71
# 2020-02-27     17      16.14
# 2020-02-28     17      16.29
# 2020-02-29     25      17.57
# 2020-03-01     32      19.86
# 2020-03-02     55      25.43
# 2020-03-03     74      33.71
# 2020-03-04    107      46.71
# 2020-03-05    184      70.57
# 2020-03-06    237     102.00
# 2020-03-07    403     156.00
# 2020-03-08    519     225.57
# 2020-03-09    594     302.57
# 2020-03-10    782     403.71
# 2020-03-11   1147     552.29

# %%
#Create a simple moving average (SMA) - 2 weeks
df['14-day-SMA'] = df['total'].rolling (window = 14).mean() #Window is in relation to data

# %%
df.plot(figsize=(12,5));

# %%
df['EWMA-7'] = df['total'].ewm (span = 7).mean()
df[['total', 'EWMA-7']].plot(figsize=(12,5));

# %%
#Exponential Weighted Moving Average - EWMA 2 weeks
df['EWMA-14'] = df['total'].ewm (span = 14).mean()
df[['total', 'EWMA-14']].plot(figsize=(12,5));
